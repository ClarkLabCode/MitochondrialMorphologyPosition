# %%
import pandas
import sys
sys.path.append(".")

from lib import mesh

# %%
mito_df = pandas.read_csv("data/pni_mito_analysisids_fullstats.csv", index_col=0)

# %%
mito_df
# Out:
#          mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  bbox_beg_x_vx  \
# mito_id
# 2740474   274528         91786         54770          1149          90910
# 1118099   330204         62682         57352           963          62072
# 2496428    82572         86324         49084          1425          86108
# 1886895    87536         76536         38810          1592          76166
# 1649845   984232         71966         39020          1221          71236
# ...          ...           ...           ...           ...            ...
# 3269438   506620        100990         43380          2035         100778
# 3489324   525496        104716         45150           818         104284
# 2850258   536892         92708         53420           447          91974
# 3281084   573244        100406         49938          1748          99882
# 3943527   574448        112738         48442           258         112164
#
#          bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  bbox_end_y_vx  \
# ...

# %%
import urllib3
urllib3.disable_warnings()

# %%
for cell_id, sr in mito_df.groupby("cellid"):
    print(cell_id)
    mito_ids=sr.index.values
    mesh.download_meshes(mito_ids)
# Out:
# 648518346349491311
# ...
